# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
# Out:
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
# %%time
data = pd.read_excel('indeed_results_pp_2020-04-25.xlsx')

# %%
data.head()
# Out:
#                                                Title  Location  \
# 0  delivery drivers delivery executives delivery ...  Guwahati
# 1        primary teacher relocation to chitrakoot up  Guwahati
# 2                                   graphic designer  Guwahati
# 3           sales executive kitchenware and utensils  Guwahati
# 4                        digital marketing executive  Guwahati
#
#                              Company              Salary  Sponsored  \
# 0                        Ride Swiggy   25000 35000 month  Sponsored
# 1  Ashok Public School Chitrakoot UP                 NaN  Sponsored
# 2                   Supermark Agency   15000 20000 month  Sponsored
# 3                   Global Prospects  175000 250000 year    Organic
# 4                   Global Prospects  100000 150000 year    Organic
#
#                                          Description        Time  \
# 0  official job posted from swiggy join swiggy fa...  2019-11-15
# ...

# %%
data.isnull().sum()
# Out:
# Title                      0
# Location                   0
# Company                    0
# Salary                 32834
# Sponsored                  0
# Description            45918
# Time                       0
# Salary_Unit_Month          0
# Salary_Unit_Year           0
# Salary_Unit_Week           0
# Salary_Unit_Day            0
# Salary_Unit_Hour           0
# Salary_New             32834
# Salary_Average             0
# Job_Type_Part_Time         0
# Job_Type_Full_Time         0
# XP_Experience              0
# XP_Fresher                 0
# Gender                     0
# Gender_Male                0
# Gender_Female              0
# Education_Tenth            0
# Education_Twelvth          0
# Education_Bachelors        0
# Education_Masters          0
# Education_Doctorate        0
# Skills_Description     49003
# Skills_Title           56820
# Skills                 46775
# Position_Junior            0
# Position_Senior            0
# Internship                 0
# ...

# %%
data.shape
# Out:
# (63828, 33)

# %%
data.dropna(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-cc8a324f0070> in <module>
# ----> 1 data.dropna(data[['Education_Tenth','Education_Twelvth','Education_Bachelors','Education_Masters','Education_Doctorate','XP_Experience']])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4570                                        axis=ax)
#    4571         else:
# -> 4572             axis = self._get_axis_number(axis)
#    4573             agg_axis = 1 - axis
#    4574
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     349     @classmethod
#     350     def _get_axis_number(cls, axis):
# --> 351         axis = cls._AXIS_ALIASES.get(axis, axis)
#     352         if is_integer(axis):
#     353             if axis in cls._AXIS_NAMES:
#
# ...

# %%
data.shape
# Out:
# (356, 33)

# %%
x = data[['Education_Tenth','Education_Twelvth','Education_Bachelors','Education_Masters','Education_Doctorate','XP_Experience']].values

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
sc = MinMaxScaler(feature_range=(0, 1))
y = sc.fit_transform(data['Salary_Average'].values.reshape(-1, 1))

# %%
lin = LinearRegression()

# %%
lin.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = lin.predict(x)

# %%
from sklearn.metrics import mean_squared_error

# %%
print('Accuracy of LR',mean_squared_error(y_pred,y))
# Out:
# Accuracy of LR 0.02348896998040886

# %%
data
# Out:
#                                                    Title  \
# 23905             web designer photoshop html css expert
# 47846                          software developer mumbai
# 47918  advance front end development reactjs openings...
# 47921  urgently required react js developers with min...
# 48217                         trainee software developer
# 49779                       sr machine learning engineer
# 50746                                sr nodejs developer
# 50748                  full stack nodejs react developer
# 50750                                 software developer
# 50751                              sr software developer
# 50789                          machine learning engineer
# 50899                                front end developer
# 50918                            software developer java
# 51000                    software developer fresher 2019
# 51007                                front end developer
# ...

# %%
acc = 1 - mean_squared_error(y_pred,y)

# %%
print("Accuracy:",acc)
# Out:
# Accuracy: 0.9765110300195912
